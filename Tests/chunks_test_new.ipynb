# %%
# !pip uninstall purecpp_libs purecpp_extract purecpp_chunks_clean

# %%
# !pip install purecpp_libs==0.0.10 purecpp_extract==0.0.10 purecpp_chunks_clean==0.0.10 purecpp_embed==0.0.10
# Out:
# Requirement already satisfied: purecpp_libs==0.0.10 in /usr/local/lib/python3.11/dist-packages (0.0.10)
# Requirement already satisfied: purecpp_extract==0.0.10 in /usr/local/lib/python3.11/dist-packages (0.0.10)
# Requirement already satisfied: purecpp_chunks_clean==0.0.10 in /usr/local/lib/python3.11/dist-packages (0.0.10)
# Requirement already satisfied: purecpp_embed==0.0.10 in /usr/local/lib/python3.11/dist-packages (0.0.10)
# Requirement already satisfied: auditwheel in /usr/local/lib/python3.11/dist-packages (from purecpp_chunks_clean==0.0.10) (6.3.0)
# Requirement already satisfied: build in /usr/local/lib/python3.11/dist-packages (from purecpp_chunks_clean==0.0.10) (1.2.2.post1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from purecpp_chunks_clean==0.0.10) (2.32.3)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from purecpp_chunks_clean==0.0.10) (0.45.1)
# Requirement already satisfied: pybind11 in /usr/local/lib/python3.11/dist-packages (from purecpp_chunks_clean==0.0.10) (2.13.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from purecpp_chunks_clean==0.0.10) (75.2.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from auditwheel->purecpp_chunks_clean==0.0.10) (24.2)
# Requirement already satisfied: pyelftools>=0.24 in /usr/local/lib/python3.11/dist-packages (from auditwheel->purecpp_chunks_clean==0.0.10) (0.32)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.11/dist-packages (from build->purecpp_chunks_clean==0.0.10) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->purecpp_chunks_clean==0.0.10) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->purecpp_chunks_clean==0.0.10) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->purecpp_chunks_clean==0.0.10) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->purecpp_chunks_clean==0.0.10) (2025.1.31)

# %%
# !git clone https://github.com/PureAI-Tools/Tests.git # comentar isso no jupiter local
#API_KEY = ""
# import os
# os.environ["..."] = ""
# Out:
# fatal: destination path 'Tests' already exists and is not an empty directory.

# %%
import purecpp_extract as ext
import purecpp_chunks_clean as cc
import purecpp_embed as emb

# %%
#verificar o tempo
pdf_loader = ext.PDFLoader("Tests/pdfs/1984.pdf") # Sobrecarregar pra poder passar uma lista
pdf = pdf_loader.Load() # pra q seria bom isso de fazer o load depois?

# %%
# pdf_loader3 = ext.PDFLoader(["Tests/pdfs/1984.pdf", "Tests/pdfs/within-a-budding-grove.pdf"] )

# %%
pdf_loader2 = ext.PDFLoader("Tests/pdfs")
pdf2 = pdf_loader2.Load()

# %%
pdf_loader

# %%
pdf_loader2

# %%
pdf
# Out:
# [Document(metadata={"source":"Tests/pdfs/1984.pdf"}, page_content="Download free eBooks of classic literature, books and \r\nnovels at Planet eBook. Subscribe to ou...")]

# %%
pdf2
# Out:
# [Document(metadata={"source":"Tests/pdfs/within-a-budding-grove.pdf"}, page_content="Within A Budding Grove \r\nBy Marcel Proust \r\nTranslated by C.K. Scott Moncrieff\nPublished by ..."),
#  Document(metadata={"source":"Tests/pdfs/the-idiot.pdf"}, page_content="Download free eBooks of classic literature, books and \r\nnovels at Planet eBook. Subscribe to ou..."),
#  Document(metadata={"source":"Tests/pdfs/Resumo-Modelos-Atomicos.pdf"}, page_content="Veja a evolução dos modelos atômicos: Demócrito; \r\nDalton; Thomson; Rutherford; e Niels Boh..."),
#  Document(metadata={"source":"Tests/pdfs/erewhon.pdf"}, page_content="Download free eBooks of classic literature, books and \r\nnovels at Planet eBook. Subscribe to ou..."),
#  Document(metadata={"source":"Tests/pdfs/recursive/Resumo-Modelos-Atomicos.pdf"}, page_content="Veja a evolução dos modelos atômicos: Demócrito; \r\nDalton; Thomson; Rutherford; e Niels Boh..."),
#  Document(metadata={"source":"Tests/pdfs/anna-karenina.pdf"}, page_content="Anna Karenina \r\nBy Leo Tolstoy\r\nTranslated by Constance Garnett\nPublished by Planet eBook. V..."),
#  Document(metadata={"source":"Tests/pdfs/oliver-twist.pdf"}, page_content="Download free eBooks of classic literature, books and \r\nnovels at Planet eBook. Subscribe to ou..."),
#  Document(metadata={"source":"Tests/pdfs/frankenstein.pdf"}, page_content="Download free eBooks of classic literature, books and \r\nnovels at Planet eBook. Subscribe to ou..."),
#  Document(metadata={"source":"Tests/pdfs/a-christmas-carol.pdf"}, page_content="Download free eBooks of classic literature, books and \r\nnovels at Planet eBook. Subscribe to ou..."),
#  Document(metadata={"source":"Tests/pdfs/the-odyssey.pdf"}, page_content="Download free eBooks of classic literature, books and \r\nnovels at Planet eBook. Subscribe to ou..."),
#  Document(metadata={"source":"Tests/pdfs/moby-dick.pdf"}, page_content="Download free eBooks of classic literature, books and \r\nnovels at Planet eBook. Subscribe to ou..."),
#  Document(metadata={"source":"Tests/pdfs/1984.pdf"}, page_content="Download free eBooks of classic literature, books and \r\nnovels at Planet eBook. Subscribe to ou...")]

# %%
docxLoader = ext.DOCXLoader("Tests/pdfs/1984.pdf") # dar erro tipo errado
docxLoader2 = ext.DOCXLoader("Tests/pdfs/1984.pdf") # dar erro tipo errado

# %%
docx = docxLoader.Load() # dar erro
docx2 = docxLoader2.Load() # dar erro

# %%
docx
# Out:
# []

# %%
docx2
# Out:
# []

# %%
docxLoader = ext.DOCXLoader("Tests/docx/1984.pdf") # dar erro caminho
docxLoader2 = ext.DOCXLoader("Tests/docx/1984.pdf") # dar erro

# %%
docxLoader = ext.DOCXLoader("Tests/docxs/sample1.docx")
docxLoader2 = ext.DOCXLoader("Tests/docxs/")

# %%
docx = docxLoader.Load() # dar erro
docx2 = docxLoader2.Load() # dar erro

# %%
docx
# Out:
# [Document(metadata={"source":"Tests/docxs/sample1.docx"}, page_content="Demonstration of DOCX support in calibre\nThis document demonstrates the ability of the calibre D...")]

# %%
docx2
# Out:
# [Document(metadata={"source":"Tests/docxs/sample1.docx"}, page_content="Demonstration of DOCX support in calibre\nThis document demonstrates the ability of the calibre D..."),
#  Document(metadata={"source":"Tests/docxs/teste-2020-07.docx"}, page_content="Já me cansei de ficar por aíVagando sem destino a chorar por vocêApostei tudo que tinha e perd..."),
#  Document(metadata={"source":"Tests/docxs/sample4.docx"}, page_content="Video provides a powerful way to help you prove your point. When you click Online Video, you can ...")]

# %%
# opt_struct = pdf_loader.GetTextContent("1984") # N retorna um tipo string

# %%
#Implementar contador de paginas ou caractere pra paginas?

# %%
pdf[0]
# Out:
# Document(metadata={"source":"Tests/pdfs/1984.pdf"}, page_content="Download free eBooks of classic literature, books and \r\nnovels at Planet eBook. Subscribe to ou...")

# %%
pdf[0].page_content
# Out:
# 'Download free eBooks of classic literature, books and \r\nnovels at Planet eBook. Subscribe to our free eBooks blog \r\nand email newsletter.\r\n1984\r\nBy George Orwell\n\x18 1984\r\nPart One\nFree eBooks at Planet eBook.com \x18\r\nChapter 1\r\nI\r\nt was a bright cold day in April, and the clocks were strik\x02ing thirteen. Winston Smith, his chin nuzzled into his \r\nbreast in an effort to escape the vile wind, slipped quickly \r\nthrough the glass doors of Victory Mansions, though not \r\nquickly enough to prevent a swirl of gritty dust from enter\x02ing along with him.\r\nThe hallway smelt of boiled cabbage and old rag mats. At \r\none end of it a coloured poster, too large for indoor display, \r\nhad been tacked to the wall. It depicted simply an enor\x02mous face, more than a metre wide: the face of a man of \r\nabout forty-five, with a heavy black moustache and rugged\x02ly handsome features. Winston made for the stairs. It was \r\nno use trying the lift. Even at the best of times it was sel\x02dom working, and at present the electric current was cut \r\noff during daylight hours. It was part of the economy drive \r\nin preparation for Hate Week. The flat was seven flights up, \r\nand Winston, who was thirty-nine and had a varicose ulcer \r\nabove his right ankle, went slowly, resting several times on \r\nthe way. On each landing, opposite the lift-shaft, the poster \r\nwith the enormous face gazed from the wall. It was one of \r\nthose pictures which are so contrived that the eyes follow \r\nyou about when you move. BIG BROTHER IS WATCHING \r\nYOU, the caption beneath it ran.\r\nInside the flat a fruity voice was reading out a list of fig-\n1984\r\nures which had something to do with the production of \r\npig-iron. The voice came from an oblong metal plaque like \r\na dulled mirror which formed part of the surface of the \r\nright-hand wall. Winston turned a switch and the voice \r\nsank somewhat, though the words were still distinguish\x02able. The instrument (the telescreen, it was called) could be \r\ndimmed, but there was no way of shutting it off complete\x02ly. He moved over to the window: a smallish, frail figure, \r\nthe meagreness of his body merely emphasized by the blue \r\noveralls which were the uniform of the party. His hair was \r\nvery fair, his face naturally sanguine, his skin roughened by \r\ncoarse soap and blunt razor blades and the cold of the win\x02ter that had just ended.\r\nOutside, even through the shut window-pane, the world \r\nlooked cold. Down in the street little eddies of wind were \r\nwhirling dust and torn paper into spirals, and though the \r\nsun was shining and the sky a harsh blue, there seemed \r\nto be no colour in anything, except the posters that were \r\nplastered everywhere. The blackmoustachio’d face gazed \r\ndown from every commanding corner. There was one on \r\nthe house-front immediately opposite. BIG BROTHER IS \r\nWATCHING YOU, the caption said, while the dark eyes \r\nlooked deep into Winston’s own. Down at street level an\x02other poster, torn at one corner, flapped fitfully in the wind, \r\nalternately covering and uncovering the single word IN\x02GSOC. In the far distance a helicopter skimmed down \r\nbetween the roofs, hovered for an instant like a bluebottle, \r\nand darted away again with a curving flight. It was the po\x02lice patrol, snooping into people’s windows. The patrols did \nFree eBooks at Planet eBook.com \x18\r\nnot matter, however. Only the Thought Police mattered.\r\nBehind Winston’s back the voice from the telescreen was \r\nstill babbling away about pig-iron and the overfulfilment \r\nof the Ninth Three-Year Plan. The telescreen received and \r\ntransmitted simultaneously. Any sound that Winston made, \r\nabove the level of a very low whisper, would be picked up by \r\nit, moreover, so long as he remained within the field of vi\x02sion which the metal plaque commanded, he could be seen \r\nas well as heard. There was of course no way of know ...

# %%
# pdf.page_content

# %%
print(type(pdf[0]))
for item in dir(pdf[0]):
    print(item)
print(type(dir(pdf[0])))
# help(opt_struct)
# Out:
# <class 'purecpp_libs.purecpp_libs.RAGDocument'>
# StringRepr
# __class__
# __delattr__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __getstate__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# _pybind11_conduit_v1_
# embedding
# metadata
# page_content
# <class 'list'>

# %%
for attr_name in dir(pdf[0]):
    if not attr_name.startswith("__"):  # Ignora atributos internos
        try:
            value = getattr(pdf[0], attr_name)
            if attr_name == "page_content":
                print(f"{attr_name}: Is a list of {len(value)} Pages")
                print(f"Page 0 {attr_name} :\n{value[0]} ")
            else:
              print(f"{attr_name}: {value}")
            print("----------------------------------------------")
        except AttributeError:
            print(f"{attr_name}: [não acessível]")
# Out:
# StringRepr: <bound method PyCapsule.StringRepr of Document(metadata={"source":"Tests/pdfs/1984.pdf"}, page_content="Download free eBooks of classic literature, books and \r\nnovels at Planet eBook. Subscribe to ou...")>
# ----------------------------------------------
# _pybind11_conduit_v1_: <bound method PyCapsule._pybind11_conduit_v1_ of Document(metadata={"source":"Tests/pdfs/1984.pdf"}, page_content="Download free eBooks of classic literature, books and \r\nnovels at Planet eBook. Subscribe to ou...")>
# ----------------------------------------------
# embedding: None
# ----------------------------------------------
# metadata: {'source': 'Tests/pdfs/1984.pdf'}
# ----------------------------------------------
# page_content: Is a list of 612305 Pages
# Page 0 page_content :
# D
# ----------------------------------------------

# %%
# help(pdf_loader)

# %%
# 2) CHUNKANDO COM ChunkDefault
#    (divide texto em blocos de 300 chars, com overlap=50)
# default_chunker = cc.ChunkDefault(chunk_size=300, overlap=50)
default_chunker = cc.ChunkDefault(50, 10) # poderia passar o item ja aqui
default_chunker2 = cc.ChunkDefault(50, 10)

# %%
# std::vector<RAGLibrary::Document> ProcessSingleDocument(RAGLibrary::LoaderDataStruct &item);
default_docs = default_chunker.ProcessDocuments(docx)

# %%
default_docs2 = default_chunker2.ProcessDocuments(docx2, max_workers=2)

# %%
print(f"ChunkDefault(50, 10) from  documents.size={len(default_docs)}")
print(f"ChunkDefault(50, 10) from  documents.size={len(default_docs2)}")
# Out:
# ChunkDefault(50, 10) from  documents.size=197
# ChunkDefault(50, 10) from  documents.size=15422

# %%
default_docs[0]
# Out:
# Document(metadata={"source":"Tests/docxs/sample1.docx"}, page_content="Demonstration of DOCX support in calibre\nThis docu")

# %%
print(type(default_docs[0])) # purecpp_libs.purecpp_libs.RAGDocument
for item in dir(default_docs[0]):
    print(item)
# Out:
# <class 'purecpp_libs.purecpp_libs.RAGDocument'>
# StringRepr
# __class__
# __delattr__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __getstate__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# _pybind11_conduit_v1_
# embedding
# metadata
# page_content

# %%
print("-----------------------------------------------------------------------------------------")
print("default")
list_default_docs = []
# Garantir que temos ao menos 3 elementos
n = len(default_docs)
first_n = default_docs[:3]            # primeiros 3
last_n = default_docs[-3:] if n >= 3 else []  # últimos 3 (sem repetir os primeiros)
# Adiciona os page_content dos primeiros
for i, doc in enumerate(first_n):
    print(f"Primeiro [{i}] METADATA =>", doc.metadata)
    list_default_docs.append(doc.page_content)
# Adiciona os page_content dos últimos
for i, doc in enumerate(last_n):
    print(f"Último [{n - 3 + i}] METADATA =>", doc.metadata)
    list_default_docs.append(doc.page_content)

print("-----------------------------------------------------------------------------------------")
print("default 2")
list_default_docs2 = []
# Garantir que temos ao menos 3 elementos
n = len(default_docs2)
first_n = default_docs2[:3]            # primeiros 3
last_n = default_docs2[-3:] if n >= 3 else []  # últimos 3 (sem repetir os primeiros)
# Adiciona os page_content dos primeiros
for i, doc in enumerate(first_n):
    print(f"Primeiro [{i}] METADATA =>", doc.metadata)
    list_default_docs2.append(doc.page_content)
# Adiciona os page_content dos últimos
for i, doc in enumerate(last_n):
    print(f"Último [{n - 3 + i}] METADATA =>", doc.metadata)
    list_default_docs2.append(doc.page_content)
print("-----------------------------------------------------------------------------------------")
# Out:
# -----------------------------------------------------------------------------------------
# default
# Primeiro [0] METADATA => {'source': 'Tests/docxs/sample1.docx'}
# Primeiro [1] METADATA => {'source': 'Tests/docxs/sample1.docx'}
# Primeiro [2] METADATA => {'source': 'Tests/docxs/sample1.docx'}
# Último [194] METADATA => {'source': 'Tests/docxs/sample1.docx'}
# Último [195] METADATA => {'source': 'Tests/docxs/sample1.docx'}
# Último [196] METADATA => {'source': 'Tests/docxs/sample1.docx'}
# -----------------------------------------------------------------------------------------
# default 2
# Primeiro [0] METADATA => {'source': 'Tests/docxs/sample1.docx'}
# Primeiro [1] METADATA => {'source': 'Tests/docxs/sample1.docx'}
# Primeiro [2] METADATA => {'source': 'Tests/docxs/sample1.docx'}
# Último [15419] METADATA => {'source': 'Tests/docxs/sample4.docx'}
# Último [15420] METADATA => {'source': 'Tests/docxs/sample4.docx'}
# Último [15421] METADATA => {'source': 'Tests/docxs/sample4.docx'}
# -----------------------------------------------------------------------------------------

# %%
for i, doc in enumerate(list_default_docs):
    print(f" {i}:  {doc} ...")
print("-----------------------------------------------------------------------------------------")

for i, doc in enumerate(list_default_docs2):
    print(f" {i}:  {doc} ...")
print("-----------------------------------------------------------------------------------------")
# Out:
#  0:  Demonstration of DOCX support in calibre
# This docu ...
#  1:
# This document demonstrates the ability of the cal ...
#  2:  of the calibre DOCX Input plugin to convert the va ...
#  3:  l and very relevant public service announcement.
# W ...
#  4:  ncement.
# We now resume our normal programming
# Four ...
#  5:  mming
# Four
#  ...
# -----------------------------------------------------------------------------------------
#  0:  Demonstration of DOCX support in calibre
# This docu ...
#  1:
# This document demonstrates the ability of the cal ...
#  2:  of the calibre DOCX Input plugin to convert the va ...
#  3:  nt. If you need to stop reading before you reach t ...
#  4:  ou reach the end, Word remembers where you left of ...
#  5:  ou left off - even on another device.
#  ...
# -----------------------------------------------------------------------------------------

# %%
try:
    openai_emb = cc.EmbeddingOpeanAI(
        list_default_docs,
        API_KEY,
    )
    print(f"[EmbeddingOpeanAI] Embedding gerada com dim={len(openai_emb[0])}")
    print(type(openai_emb))
    for i, item in enumerate(openai_emb):
        print(f"{i}:")
        print(type(item))
        print(item)

    # (c) Normalizar a primeira embedding
    print("\n\n\n")
    cc.NormalizeEmbeddings(openai_emb[0])
except Exception as e:
    print("Não foi possível gerar embeddings com OpenAI (talvez sem chave válida):", e)
print()
# Out:
# Não foi possível gerar embeddings com OpenAI (talvez sem chave válida): {"code":null,"message":"You didn't provide an API key. You need to provide your API key in an Authorization header using Bearer auth (i.e. Authorization: Bearer YOUR_KEY), or as the password field (with blank username) if you're accessing the API from your browser and are prompted for a username and password. You can obtain an API key from https://platform.openai.com/account/api-keys.","param":null,"type":"invalid_request_error"}

# %%
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# 3) CHUNKANDO COM ChunkCount (divide texto a cada pontuação final, usando regex, overlap menor)
# ChunkCount(const std::string &count_unit, const int overlap = 600, const int count_threshold = 1);
count_chunker = cc.ChunkCount("regex:[.!?]+", overlap=10, count_threshold=1)
count_chunker2 = cc.ChunkCount("regex:[.!?]+", overlap=10, count_threshold=1)

# %%
# std::vector<RAGLibrary::Document> ProcessData(RAGLibrary::LoaderDataStruct &item);
count_docs = count_chunker.ProcessData(item_struct[0])
# std::vector<RAGLibrary::Document> ProcessData(const std::vector<RAGLibrary::LoaderDataStruct> &items, int max_workers = 4);
count_docs2 = count_chunker2.ProcessData(item_struct, max_workers=5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-2058f62f8860> in <cell line: 0>()
#       1 # std::vector<RAGLibrary::Document> ProcessData(RAGLibrary::LoaderDataStruct &item);
# ----> 2 count_docs = count_chunker.ProcessData(item_struct[0])
#       3 # std::vector<RAGLibrary::Document> ProcessData(const std::vector<RAGLibrary::LoaderDataStruct> &items, int max_workers = 4);
#       4 count_docs2 = count_chunker2.ProcessData(item_struct, max_workers=5)
#
# AttributeError: 'purecpp_chunks_clean.purecpp_chunks_clean.ChunkCou' object has no attribute 'ProcessData'

# %%
print(f"ChunkCount from {len(count_docs)}")
print(f"ChunkCount2 from {len(count_docs2)}")

# %%
print("-----------------------------------------------------------------------------------------")
print("Count")
list_count_docs = []
prev_m = None
for i, doc in enumerate(count_docs):
    if i > 3: break
    if doc.metadata != prev_m or prev_m is None:
        print(" METADATA =>", doc.metadata)
    print(type(doc))
    print(type(doc.page_content))
    list_count_docs.append(doc.page_content)
    print(f"{i}:  {doc}")
    prev_m = doc.metadata

print("-----------------------------------------------------------------------------------------")
print("Count 2")
list_count_docs2 = []
prev_m = None
for i, doc in enumerate(count_docs2):
    if i > 3: break
    if doc.metadata != prev_m or prev_m is None:
        print(" METADATA =>", doc.metadata)
    print(type(doc))
    print(type(doc.page_content))
    list_count_docs2.append(doc.page_content)
    print(f"{i}:  {doc}")
    prev_m = doc.metadata
print("-----------------------------------------------------------------------------------------")

# %%
for i, doc in enumerate(list_count_docs):
    print(f" {i}:  {doc[:70]} ...")
print("-----------------------------------------------------------------------------------------")

for i, doc in enumerate(list_count_docs2):
    print(f" {i}:  {doc[:70]} ...")
print("-----------------------------------------------------------------------------------------")

# %%
# 4) USANDO ALGUMAS FUNÇÕES DE CHUNKCOMMONS MANUALMENTE
#    Exemplo:  (a) Dividir manualmente um texto e (b) Gerar embeddings via OpenAI
#    (c) Normalizar e exibir a embedding

# (a) SplitText manual
text_example = ["Este é um texto de exemplo.", "Ele será unido e fatiado em 50 chars com 10 de overlap."]
splitted = cc.SplitText(text_example, overlap=10, chunk_size=50)
print(f"[SplitText] Gerei {len(splitted)} pedaços. Primeiro pedaço:\n   {splitted[0]}")

# %%
# 5) USANDO FUNÇÕES DE EMBEDDINGS MANUALMENTE
#    Exemplo:  (a) Gerar embeddings via OpenAI
#    (b) Normalizar e exibir a embedding
try:
    openai_emb = cc.EmbeddingOpeanAI(
        list_count_docs, # tem q ser uma lista de string
        API_KEY,
    )
    print(f"[EmbeddingOpeanAI] Embedding gerada com dim={len(openai_emb[0])} ")
    for i, item in enumerate(openai_emb):
        print(f"{i}:")
        print(type(item))
        print(item)

    cc.NormalizeEmbeddings(openai_emb[0])
except Exception as e:
    print("Não foi possível gerar embeddings com OpenAI (talvez sem chave válida):", e)
print()
